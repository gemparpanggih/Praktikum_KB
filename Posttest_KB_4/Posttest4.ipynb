# %% [markdown]
# # IMPORT

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv('employee_promotion.csv')

# %%
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  awards_won  avg_training_score  is_promoted
# 0                  8           0                49.0  no_promoted
# ...

# %% [markdown]
# # Data Split
# ## x = Data Frame tanpa label
# ## y = Label

# %%
y = df.iloc[:,-1]
X = df.iloc[:,:-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
print("Dimensi X_train : ", X_train.shape)
print("Dimensi X_train : ", X_test.shape)
print("Dimensi y_train : ", y_train.shape)
print("Dimensi y_test : ", y_test.shape)
# Out:
# Dimensi X_train :  (38365, 12)
# Dimensi X_train :  (16443, 12)
# Dimensi y_train :  (38365,)
# Dimensi y_test :  (16443,)

# %% [markdown]
# # Data Normalisasi

# %%
df2 = df[['age', 'no_of_trainings', 'avg_training_score']]
df2.head()
# Out:
#    age  no_of_trainings  avg_training_score
# 0   35                1                49.0
# 1   30                1                60.0
# 2   34                1                50.0
# 3   39                2                50.0
# 4   45                1                73.0

# %%
norm = MinMaxScaler()

# %%
Scaled_data = norm.fit_transform(df2)

# %%
print("Nilai Data Sebelum Scaling : ")
print(df2)
print("Nilai Standar Deviasi: \n", np.std(df2))

print("\n\n Nilai Data setelah Scaling : ")
print(Scaled_data)
print("Nilai Standar Deviasi: ", np.std(Scaled_data))
# Out:
# Nilai Data Sebelum Scaling :
#        age  no_of_trainings  avg_training_score
# 0       35                1                49.0
# 1       30                1                60.0
# 2       34                1                50.0
# 3       39                2                50.0
# 4       45                1                73.0
# ...    ...              ...                 ...
# 54803   48                1                78.0
# 54804   37                1                56.0
# 54805   27                1                79.0
# 54806   29                1                 NaN
# 54807   27                1                49.0
#
# [54808 rows x 3 columns]
# Nilai Standar Deviasi:
#  age                    7.660099
# no_of_trainings        0.609258
# avg_training_score    13.521781
# dtype: float64
#
#
#  Nilai Data setelah Scaling :
# [[0.375      0.         0.16666667]
#  [0.25       0.         0.35      ]
#  [0.35       0.         0.18333333]
#  ...
#  [0.175      0.         0.66666667]
# ...

# %% [markdown]
# # Data Standarisasi

# %%
df3 = df[['age', 'no_of_trainings', 'avg_training_score']]
df3.head()
# Out:
#    age  no_of_trainings  avg_training_score
# 0   35                1                49.0
# 1   30                1                60.0
# 2   34                1                50.0
# 3   39                2                50.0
# 4   45                1                73.0

# %%
stand = StandardScaler()

# %%
Scaled_data = stand.fit_transform(df3)

# %%
print("Nilai Data Sebelum Scaling : ")
print(df3)
print("Nilai Standar Deviasi: \n", np.std(df3))

print("\n\n Nilai Data Setelah Scaling : ")
print(Scaled_data)
print("Nilai Standar Deviasi: ", np.std(Scaled_data))
# Out:
# Nilai Data Sebelum Scaling :
#        age  no_of_trainings  avg_training_score
# 0       35                1                49.0
# 1       30                1                60.0
# 2       34                1                50.0
# 3       39                2                50.0
# 4       45                1                73.0
# ...    ...              ...                 ...
# 54803   48                1                78.0
# 54804   37                1                56.0
# 54805   27                1                79.0
# 54806   29                1                 NaN
# 54807   27                1                49.0
#
# [54808 rows x 3 columns]
# Nilai Standar Deviasi:
#  age                    7.660099
# no_of_trainings        0.609258
# avg_training_score    13.521781
# dtype: float64
#
#
#  Nilai Data Setelah Scaling :
# [[ 0.02559817 -0.41527615 -1.08803998]
#  [-0.62713488 -0.41527615 -0.27453765]
#  [-0.10494844 -0.41527615 -1.01408522]
#  ...
# ...

# %% [markdown]
# # Data Cleaning Nilai Null

# %%
df.isna().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# awards_won                 0
# avg_training_score      2560
# is_promoted                0
# dtype: int64

# %%
df.dtypes
# Out:
# employee_id               int64
# department               object
# region                   object
# education                object
# gender                   object
# recruitment_channel      object
# no_of_trainings           int64
# age                       int64
# previous_year_rating    float64
# length_of_service         int64
# awards_won                int64
# avg_training_score      float64
# is_promoted              object
# dtype: object

# %%
imputer = SimpleImputer(strategy='most_frequent' )

# %%
df["education"] = imputer.fit_transform(df[["education"]])

# %%
df.isna().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education                  0
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# awards_won                 0
# avg_training_score      2560
# is_promoted                0
# dtype: int64

# %%
imputer2 = SimpleImputer(strategy='mean' )

# %%
df["previous_year_rating"] = imputer2.fit_transform(df[["previous_year_rating"]])
df["avg_training_score"] = imputer2.fit_transform(df[["avg_training_score"]])

# %%
df.isna().sum()
# Out:
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# awards_won              0
# avg_training_score      0
# is_promoted             0
# dtype: int64

# %% [markdown]
# # Data Cleaning Nilai Duplikat

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [employee_id, department, region, education, gender, recruitment_channel, no_of_trainings, age, previous_year_rating, length_of_service, awards_won, avg_training_score, is_promoted]
# Index: []

# %%
df.iloc[0]
# Out:
# employee_id                         65438
# department              Sales & Marketing
# region                           region_7
# education                Master's & above
# gender                                  f
# recruitment_channel              sourcing
# no_of_trainings                         1
# age                                    35
# previous_year_rating                  5.0
# length_of_service                       8
# awards_won                              0
# avg_training_score                   49.0
# is_promoted                   no_promoted
# Name: 0, dtype: object

# %%
df = df.append(df.iloc[0:100])
# Out:
# C:\Users\NITRO 5\AppData\Local\Temp\ipykernel_8544\324845436.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df.iloc[0:100])

# %%
df[df.duplicated()]
# Out:
#     employee_id         department     region         education gender  \
# 0         65438  Sales & Marketing   region_7  Master's & above      f
# 1         65141         Operations  region_22        Bachelor's      m
# 2          7513  Sales & Marketing  region_19        Bachelor's      m
# 3          2542  Sales & Marketing  region_23        Bachelor's      m
# 4         48945         Technology  region_26        Bachelor's      m
# ..          ...                ...        ...               ...    ...
# 95        43923          Analytics  region_14        Bachelor's      m
# 96        64109         Technology  region_26        Bachelor's      f
# 97        41983         Operations   region_2        Bachelor's      f
# 98        21440  Sales & Marketing  region_31        Bachelor's      m
# 99        51256            Finance   region_2  Master's & above      m
#
#    recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [employee_id, department, region, education, gender, recruitment_channel, no_of_trainings, age, previous_year_rating, length_of_service, awards_won, avg_training_score, is_promoted]
# Index: []

# %% [markdown]
# # Ganti Tipe Data

# %%
df['length_of_service'] = df['length_of_service'].astype('float64')

# %%
df.dtypes
# Out:
# employee_id               int64
# department               object
# region                   object
# education                object
# gender                   object
# recruitment_channel      object
# no_of_trainings           int64
# age                       int64
# previous_year_rating    float64
# length_of_service       float64
# awards_won                int64
# avg_training_score      float64
# is_promoted              object
# dtype: object

# %%
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  awards_won  avg_training_score  is_promoted
# 0                8.0           0                49.0  no_promoted
# ...

# %% [markdown]
# # ENCODE

# %%
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  awards_won  avg_training_score  is_promoted
# 0                8.0           0                49.0  no_promoted
# ...

# %%
encoder = OneHotEncoder(sparse=False)
genderEncode = encoder.fit_transform(df[["gender"]])

# %%
gender = pd.DataFrame(genderEncode)
df = df.join(gender)
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  awards_won  avg_training_score  is_promoted    0    1
# ...

# %%
df = df.rename(columns={
    0 : 'Female',
    1 : 'Male'
})
df.head()
# Out:
#    employee_id         department     region         education gender  \
# 0        65438  Sales & Marketing   region_7  Master's & above      f
# 1        65141         Operations  region_22        Bachelor's      m
# 2         7513  Sales & Marketing  region_19        Bachelor's      m
# 3         2542  Sales & Marketing  region_23        Bachelor's      m
# 4        48945         Technology  region_26        Bachelor's      m
#
#   recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0            sourcing                1   35                   5.0
# 1               other                1   30                   5.0
# 2            sourcing                1   34                   3.0
# 3               other                2   39                   1.0
# 4               other                1   45                   3.0
#
#    length_of_service  awards_won  avg_training_score  is_promoted  Female  \
# ...

# %%
encoder = OneHotEncoder(sparse=False)
promotEncode = encoder.fit_transform(df[["is_promoted"]])

# %%
promot = pd.DataFrame(promotEncode)
df = df.join(promot)

# %%
df = df.rename(columns={
    0 : 'No Promoted',
    1 : 'Has Promoted'
})
df.head(50)
# Out:
#     employee_id         department     region         education gender  \
# 0         65438  Sales & Marketing   region_7  Master's & above      f
# 1         65141         Operations  region_22        Bachelor's      m
# 2          7513  Sales & Marketing  region_19        Bachelor's      m
# 3          2542  Sales & Marketing  region_23        Bachelor's      m
# 4         48945         Technology  region_26        Bachelor's      m
# 5         58896          Analytics   region_2        Bachelor's      m
# 6         20379         Operations  region_20        Bachelor's      f
# 7         16290         Operations  region_34  Master's & above      m
# 8         73202          Analytics  region_20        Bachelor's      m
# 9         28911  Sales & Marketing   region_1  Master's & above      m
# 10        29934         Technology  region_23        Bachelor's      m
# 11        49017  Sales & Marketing   region_7        Bachelor's      f
# ...

# %%
df.to_csv("clean_employee_promotion.csv", index=False)
